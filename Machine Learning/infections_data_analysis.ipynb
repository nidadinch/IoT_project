# %%
import numpy as np 
import pandas as pd

# %%
inf = pd.read_csv("infection.csv")
df = inf.copy()

# %%
df.isnull().any()
# Out:
# temperature    False
# hoursMild      False
# hoursMid       False
# hoursSevere    False
# dtype: bool

# %%
df.head()
# Out:
#    temperature  hoursMild  hoursMid  hoursSevere
# 0         25.5       13.0        17           26
# 1         25.0       11.0        14           21
# 2         24.4        9.5        12           19
# 3         23.9        9.0        12           18
# 4         16.7        9.0        12           19

# %%
df.describe().T
# Out:
#              count    mean        std   min   25%   50%   75%   max
# temperature   25.0  13.288   5.983332   5.6   8.9  12.2  15.6  25.5
# hoursMild     25.0  13.880   5.472050   9.0  10.0  12.0  15.0  30.0
# hoursMid      25.0  18.880   7.299087  12.0  14.0  17.0  20.0  40.0
# hoursSevere   25.0  28.560  10.840049  18.0  21.0  25.0  30.0  60.0

# %%
df.corr()
# Out:
#              temperature  hoursMild  hoursMid  hoursSevere
# temperature     1.000000  -0.676184 -0.713101    -0.707767
# hoursMild      -0.676184   1.000000  0.996408     0.997587
# hoursMid       -0.713101   0.996408  1.000000     0.998810
# hoursSevere    -0.707767   0.997587  0.998810     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df, kind = "reg")

# %%
sns.jointplot(x = "temperature", y  = "hoursMild", data = df, kind = "reg")
