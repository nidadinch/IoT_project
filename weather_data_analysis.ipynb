# %%
import numpy as np 
import pandas as pd

# %%
wd = pd.read_csv("weather_data.csv", error_bad_lines=False)
df = wd.copy()

# %%
df.isnull().any()
# Out:
# LAT        False
# LON        False
# YEAR       False
# MO         False
# DY         False
# T2M_MAX    False
# T2M_MIN    False
# T2M        False
# dtype: bool

# %%
df.head()
# Out:
#         LAT       LON  YEAR  MO  DY  T2M_MAX  T2M_MIN   T2M
# 0  40.99041  35.75761  2010   1   1    11.84    -0.24  6.13
# 1  40.99041  35.75761  2010   1   2    13.78     3.74  7.89
# 2  40.99041  35.75761  2010   1   3     6.90     1.20  3.35
# 3  40.99041  35.75761  2010   1   4     2.67    -4.31 -0.11
# 4  40.99041  35.75761  2010   1   5     3.17    -4.42 -1.90

# %%
df.describe().T
# Out:
#           count         mean       std         min         25%         50%  \
# LAT      1827.0    40.990410  0.000000    40.99041    40.99041    40.99041
# LON      1827.0    35.757610  0.000000    35.75761    35.75761    35.75761
# YEAR     1827.0  2012.001642  1.415567  2010.00000  2011.00000  2012.00000
# MO       1827.0     6.520525  3.450954     1.00000     4.00000     7.00000
# DY       1827.0    15.719759  8.806068     1.00000     8.00000    16.00000
# T2M_MAX  1827.0    17.831286  9.579773    -6.12000     9.89000    18.28000
# T2M_MIN  1827.0     6.093716  7.246317   -16.56000     0.03500     6.60000
# T2M      1827.0    11.299414  8.300437   -12.35000     4.41000    11.80000
#
#                 75%         max
# LAT        40.99041    40.99041
# LON        35.75761    35.75761
# YEAR     2013.00000  2015.00000
# MO         10.00000    12.00000
# DY         23.00000    31.00000
# T2M_MAX    25.90500    38.76000
# T2M_MIN    12.41500    20.67000
# T2M        18.58500    28.40000

# %%
df.corr()
# Out:
#          LAT  LON      YEAR        MO        DY   T2M_MAX   T2M_MIN       T2M
# LAT      NaN  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# LON      NaN  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YEAR     NaN  NaN  1.000000 -0.001857 -0.001940  0.034365  0.003936  0.018103
# MO       NaN  NaN -0.001857  1.000000  0.012245  0.244857  0.284896  0.247949
# DY       NaN  NaN -0.001940  0.012245  1.000000  0.029321  0.026986  0.030373
# T2M_MAX  NaN  NaN  0.034365  0.244857  0.029321  1.000000  0.938893  0.985154
# T2M_MIN  NaN  NaN  0.003936  0.284896  0.026986  0.938893  1.000000  0.978853
# T2M      NaN  NaN  0.018103  0.247949  0.030373  0.985154  0.978853  1.000000

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df[["T2M_MAX", "T2M_MIN", "T2M"]])
plt.xlabel("Days (1.01.2010 to 1.01.2015)")
plt.ylabel("Tempature")
plt.title("Tempature changes day-by-day")
# Out:
# Text(0.5, 1.0, 'Tempature changes day-by-day')
